# %%
# importing colour print
import simple_colors

#project details
print(simple_colors.magenta("\033[1m" + """                                       project title    :    youtube data harvesting and warehousing
                                        learner name    :    sudharsan J
                                        course          :    datascience
                                        batch           :    d101
                                        institute       :    GUVI""" + "\033[0m"))

# importing google-api-dictionary
from googleapiclient.discovery import build
from pprint import pprint

# importing pandas
import pandas as pd

# To get API key for the channel
api_key = 'AIzaSyAddeNiABJpBtGPbrJyIcrH5n8ebqlVOjU'

api_service_name = "youtube"
api_version = "v3"
channel_id = "UCggZvARaczWC4wc4E6f330w"

# To estabilish the connection between API key and 
youtube =build(
        api_service_name, api_version,developerKey = api_key)

request = youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id=channel_id
)
channel_response = request.execute()

# To get the title of channel
print(simple_colors.green("title of the channel:"))

channel_name = channel_response['items'][0]['snippet']['title']
print(channel_name)

# To get the description of channel
channel_desc = channel_response['items'][0]['snippet']['description']

# To get the uploads key
print(simple_colors.green("\nupload key of the channel:"))

channel_upload_key = channel_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
print(channel_upload_key)

# To get the date of channel publication
print(simple_colors.green("\ndate of the channel publication:"))

channel_published_date= channel_response['items'][0]['snippet']['publishedAt']
print(channel_published_date)

# To get number of views
print(simple_colors.green("\nnumber of the channel views:"))

channel_views = channel_response['items'][0]['statistics']['viewCount']
channel_views = int (channel_views)
print(channel_views)

# To get number of subscribers
print(simple_colors.green("\nnumber of the channel subscribers:"))

channel_subscribers = channel_response['items'][0]['statistics']['subscriberCount']
channel_subscribers = int (channel_subscribers)
print(channel_subscribers)

# To get the playlist id
print(simple_colors.green("\nplaylist id of channel:"))
playlist_response = youtube.channels().list(
    part='contentDetails',
    id=channel_id
).execute()
playlist_id = playlist_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
print(playlist_id)

# To get the number of videos
print(simple_colors.green("\ntotal number of channel videos:"))

channel_videos = channel_response['items'][0]['statistics']['videoCount']
channel_videos = int(channel_videos)
print(channel_videos)

# creating channel detials dictionary
print(simple_colors.green("\nchannel details dictionary:"))
channel_details = {
    'channel_name':(channel_name),
    'channel_upload_key':(channel_upload_key),
    'channel_published_date':(channel_published_date),
    'channel_views':(channel_views),
    'channel_subscribers': (channel_subscribers),
    'channel_videos': (channel_videos),
    'playlist_id':(playlist_id)
}
print(channel_details)


# Function to retrieve video details
playlist_response = youtube.channels().list(
    part='contentDetails',
    id=channel_id
).execute()

# to get the playlist name
playlist_id = playlist_response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
print(playlist_id)

video_response = youtube.playlistItems().list(
        part='snippet',
        playlistId=playlist_id,
    maxResults=1345
    ).execute()

# video ids extraction:
print(simple_colors.green("\nvideo id extraction:\n"))

def getChannelVideos(channel_id):
    video_ids = []
    
    res = youtube.channels().list( id=channel_id,
                                  part='contentDetails').execute()
    playlist_id = res['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    next_page_token = None

    while True:
       res = youtube.playlistItems().list(playlistId=playlist_id,
                                     part='snippet',
                                     pageToken = next_page_token).execute()
       for i in range(len(res['items'])):
            video_ids.append(res['items'][i]['snippet']['resourceId']['videoId'])
       next_page_token = res.get('nextPageToken')
       if next_page_token is None:
           break
    return video_ids

video_id_list = getChannelVideos(channel_id)
print(video_id_list)

#) To get the comment id
print(simple_colors.green("\nTo get the comment id:\n"))

comments_id_list =[]

video_ids = video_id_list
for video_id in video_ids:
    request = youtube.commentThreads().list(part="snippet,replies",
                                                    videoId=video_id)
    response = request.execute()
    for comment_details in response['items']:
        comments_id=comment_details['id']
        comments_id_list.append(comments_id)

print(comments_id_list)


#) To get the video id with respect to comment ids
print(simple_colors.green("\nTo get the video id with respect to comments:\n"))

comments_video_id =[]

video_ids = video_id_list
for video_id in video_ids:
    request = youtube.commentThreads().list(part="snippet,replies",
                                                    videoId=video_id)
    response = request.execute()
    for comment_details in response['items']:
        comments_videoID=comment_details['snippet']['videoId']
        comments_video_id.append(comments_videoID)

print(comments_video_id)


#) To get the comment ids
print(simple_colors.green("\nTo get the comment ids:\n"))
comments_id_list =[]
video_ids = video_id_list
for video_id in video_ids:
    request = youtube.commentThreads().list(part="snippet,replies",
                                                    videoId=video_id)
    response = request.execute()
    for comment_details in response['items']:
        comments_id=comment_details['id']
        comments_id_list.append(comments_id)
print(comments_id_list)


#) To get the comment texts
print(simple_colors.green("\nTo get the comment texts:\n"))
comments_text_list =[]
video_ids = video_id_list
for video_id in video_ids:
    request = youtube.commentThreads().list(part="snippet,replies",
                                                    videoId=video_id)
    response = request.execute()
    for comment_details in response['items']:
        comments_text=comment_details['snippet']['topLevelComment']['snippet']['textDisplay']
        comments_text_list.append(comments_text)
print(comments_text_list)

#) To get the comment authors
print(simple_colors.green("\nTo get the comment authors:\n"))

comments_authors_list =[]

video_ids = video_id_list
for video_id in video_ids:
    request = youtube.commentThreads().list(part="snippet,replies",
                                                    videoId=video_id)
    response = request.execute()
    for comment_details in response['items']:
        comments_authors=comment_details['snippet']['topLevelComment']['snippet']['authorDisplayName']
        comments_authors_list.append(comments_authors)
print(comments_authors_list)

#) To get the comment published date
print(simple_colors.green("\nTo get the comment published date:\n"))
commented_date_list =[]
video_ids = video_id_list
for video_id in video_ids:
    request = youtube.commentThreads().list(part="snippet,replies",
                                                    videoId=video_id)
    response = request.execute()
    for comment_details in response['items']:
        commented_dates=comment_details['snippet']['topLevelComment']['snippet']['publishedAt']
        commented_date_list.append(commented_dates)
print(commented_date_list)

#) To get the channel names with respect to comments
print(simple_colors.green("\nTo get the channel names with respect to comments:\n"))
corrosponding_channel_name = []
for video_id in commented_date_list:
    request = youtube.videos().list(
    part="snippet,contentDetails,statistics",
    id =video_id
)
    video_response  = request.execute()
    corrosponding_channel_name.append(channel_response['items'][0]['snippet']['title'])
print(corrosponding_channel_name)
# Out:
#                                        project title    :    youtube data harvesting and warehousing
#                                         learner name    :    sudharsan J
#                                         course          :    datascience
#                                         batch           :    d101
#                                         institute       :    GUVI
# title of the channel:
# All About Python
#
# upload key of the channel:
# UUggZvARaczWC4wc4E6f330w
#
# date of the channel publication:
# 2021-04-17T07:40:33.865779Z
#
# number of the channel views:
# 269035
#
# number of the channel subscribers:
# 2690
#
# playlist id of channel:
# UUggZvARaczWC4wc4E6f330w
#
# total number of channel videos:
# 33
#
# channel details dictionary:
# ['Ultimate speech my friend which country are you?', 'My friend please don&#39;t stop the video if you stopped then i think I&#39;ll be fail in this semester', 'I&#39;m big fan of you and especially your voice', 'That&#39;s it my friend just you&#39;ve been killing it just do th continuously videos', 'Ji do videos continuously we really miss all your stuffs and great explanation', 'why you didnt  use python key', 'Thanks a lot for the video', 'Thank you very much! This video was really helpful!', 'Where u gone 😢', 'dont use background music', 'You explained everything in under 15 minutes, thank you!', 'bruh me your telegram username. Or give me a working ig username.', 'Thanks for the video! I was looking for this for my capstone project and this helps me understand how to use the Realtime Database. I was wondering if you can make a tutorial on how to do a bidirectional synchronization between 2 database like TinyDb and Firebase Realtime Database on python.', 'why it&#39;s being sent to spam', 'Where did you get the password from?', 'The information about the port number helped me a lot, thank you', 'I still don&#39;t understand the first sign that looks like an f  in your print statement?', 'it keeps throwing an error for the text file', 'Best', 'sir, thank you for the video!!!', 'For desktop offline app? What about creating online web app like Flask using HTML and Eel?', 'Very nice tutorial', 'Is this possible without using javscript ?', 'Pyton vib', 'Sir God bless you so much, but I would love if you can create more tutorial on python eel', 'Thanks man, it helped me a lot!', 'Can&#39;t see ur right content in html page', 'Great tutorial, thank you!', 'Underrated. Very well explained. Thanks for the video', 'This video has less views than it should, owesome content dude, thank you!', 'Don&#39;t waste your time with this &quot;rest of the f*cking owl&quot; tutorial', 'I didn&#39;t knew you have this great presentation skills🔥🔥🔥,, gr8 job🙏 vishesh!', 'Great vid!', '<a href="https://www.youtube.com/watch?v=2YKzXg04oy8&amp;t=332">5:32</a> Did Joe make this API?', 'Mare bhaiya hai', 'Great video as always', 'You are awesome 👌 Can we please create more videos on python playwright?', 'Thank you. Great starter.', 'Bro that was nice. Can you please create a playwright python course. The best explanation ever man. Subbed!', 'What&#39;s up with the XSS injection prompt when I login into the demo account?', 'The last part is the gold mine! Thank you.', 'Where is the git repo to copy the code ?', 'Excellent video- you’re a great teacher bro. Thank you for uploading this.', 'The video URL on your desc points to some other irrelevant video', 'Nice video bro. When installing pip install playwright browser in vscode, i&#39;m getting failed error which says &quot;failed install chromium v100 and unable to get local issuer certificate&quot; in my company laptop. Do you have any suggestion?', 'Mare bhaiya hai', 'Gr8 Video!!', 'Check out the blog: <a href="https://www.allaboutpython.tech/2023/02/how-to-create-and-add-data-to-excel_18.html">https://www.allaboutpython.tech/2023/02/how-to-create-and-add-data-to-excel_18.html</a>', 'Exactly what I needed, thank you!', '&quot;Oh no, how will I ever complete my code HW?&quot;<br><br>Indian Youtuber: 😇', 'I am running this on Spyder.The code runs but I cannot locate where the excel file got created. Can anybody help? Where should I be looking for the excel file?', 'Indian English😅😅', 'Awesome video thanks a lot', 'Great quality content and video', 'You have great content, you don&#39;t need background music.', 'Sorry, but this is quite useless video. I know, maybe this was authors videos in beginnig of his youtube, but still. You actually did not give any knowledge to understand the concept. Maybe you are fan of the music, but it was quite distracting to me. At least you could turn it down more. Still do meditation music in this kind of videos is awfull. I missed any alternatives for this module too. Y ...
#
# To get the comment authors:
#
# ['@emmranm369', '@emmranm369', '@emmranm369', '@emmranm369', '@emmranm369', '@tehseenbaig3198', '@jasminatarmasheva', '@pedrocaillaux7745', '@aloneaneelgaming1511', '@krissradev6708', '@user-kl8xi6mw1z', '@TeeChemist', '@FujiwaraKengo', '@FalconX8027', '@pranatheerao2354', '@user-rr3jh8nq5v', '@austinokezie3716', '@chiaraegbuna50', '@user-px8kh9tl3j', '@denys2957', '@tristotech', '@PoomulusRobsBanksOnTV', '@kcvinu', '@ah89971', '@Kennethlumor', '@nicopostigo123', '@iftesamali8001', '@markalanboyd', '@mickel8068', '@tazz2010', '@killers19', '@sudhanshujha743', '@ethancooper8850', '@aniketdvd', '@itbeattime1032', '@astitvavarma1079', '@srinug85', '@stephengupwell2064', '@prashantmishra5691', '@actionknight93', '@yafethtb', '@adipear', '@mikewaters6980', '@vignesh_waran', '@NG-tc7mh', '@itbeattime1032', '@astitvavarma1079', '@AllAboutPython', '@davidbristoll195', '@aaronkempenich124', '@rushabbhimani1494', '@kalininshaw1691', '@alhassanmusah7242', '@user-dd3do3mq5z', '@atchutram9894', '@lukaschumchal7797', '@marchalmoody1009', '@Jalon_Briscoe', '@user-xz2sr1zv3e', '@user-pu1ve7hc1o', '@TudoracheIonel', '@yp4577', '@pankajbudhlakoti979', '@sandeepkumarkailasa4415', '@viomagsantos2184', '@mustafachenine7942', '@epicdestroyerxd6285', '@Thecybersecurity_EthicalHacker', '@ezcoding4454', '@TechBot919', '@Litfield', '@godofwar3702', '@garrylane8093', '@anshuverma8385', '@nikhilnikki1876', '@minhtuan299maxspeed', '@kunalrajbhar6718', '@mrme488', '@astitvavarma1079', '@AllAboutPython', '@AstraGamesStudios', '@ericpriemon1219', '@belacpp3940', '@phoenixboi3348', '@aryankaushal9466', '@rhythmdutta387', '@rohanrustagi7857', '@robinranabhat3125', '@falkschiffner6565', '@meownurmagomedov', '@itbeattime1032', '@elliekong712', '@Makash2037', '@secretmystery8305', '@getfit9133', '@ayushmishra2926', '@itbeattime1032', '@AllAboutPython', '@AstraGamesStudios', '@pet.me102', '@user-ux9lo6et1l', '@aloneaneelgaming1511', '@Mr.Dorina', '@acountdontexistanymore', '@rahimkhann6328', '@ApeiroOrAlyssa', '@clearcodee_', '@Ammarsslash', '@akduman4680', '@ashwanitiwari8234', '@sridharshini.S', '@storieswithumme4071', '@phoenixboi3348', '@clementadufu4632', '@nodirectionvlogs7237', '@xycreatives-ca', '@lucapapini6705', '@AllAboutPython', '@manjulaelumalai594', '@Emil-gn1wj', '@_vishal_19_', '@MOHNISH_K', '@a.n.naveen1492', '@Ak-gr4fj', '@devanand85', '@arunrwarrier3977', '@g_sayer_1435', '@astitvavarma1079', '@MAryan-kp3yd', '@simplescastillo6687', '@devscloud7600', '@astitvavarma1079', '@abvmoose87', '@shubham9672', '@shyamprasad3034', '@evilogkevin', '@lightprogrammer', '@joybiswas-', '@RobertPodosek', '@vadympolianskyi9304', '@basitemad655', '@astitvavarma1079', '@pranjalgupta570', '@itbeattime1032', '@prateekfx7', '@pranjalgupta570', '@itbeattime1032', '@astitvavarma1079', '@ankitasingh3907', '@Asperaetastra', '@stemp-freefire7158', '@fredeLN', '@RelaxingMusic-ts9xx', '@manurajgoel', '@okeykenneth
'2021-10-16T14:35:38Z', '2021-08-07T04:33:22Z', '2021-07-31T15:37:17Z', '2021-07-30T09:29:49Z', '2021-07-26T15:03:43Z', '2021-07-26T09:52:20Z', '2021-07-25T14:31:06Z', '2023-08-16T15:24:37Z', '2023-02-28T18:28:34Z', '2023-02-28T18:26:11Z', '2023-01-04T07:52:46Z', '2022-04-14T08:42:58Z', '2022-03-29T07:45:02Z', '2022-01-06T22:54:31Z', '2021-12-30T11: ...
#
# To get the channel names with respect to comments:
#
# ['All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', 'All About Python', ...

# %%
# to create comment details dataset in pandas
print(simple_colors.green("\nTo get the channel names with respect to comments:\n"))
import pandas as pd
df = pd.DataFrame()
df['corrosponding_channel_name']=corrosponding_channel_name
df['comments_video_id'] = comments_video_id
df['comments_id_list'] = comments_id_list
df['comments_text_list'] = comments_text_list
df['comments_authors_list']=comments_authors_list
df['commented_date_list'] = commented_date_list
df
# Out:
# To get the channel names with respect to comments:
#     corrosponding_channel_name comments_video_id            comments_id_list  \
# 0             All About Python       27V-5W3DFW0  UgwZApCeVEwi6pOpXnB4AaABAg
# 1             All About Python       8qc03BfEgyc  UgyPILoKNHcPypWF-zt4AaABAg
# 2             All About Python       8qc03BfEgyc  UgwOTpcD5oYgNKk5Z7t4AaABAg
# 3             All About Python       8qc03BfEgyc  UgzfT9exWQgw00bKGjd4AaABAg
# 4             All About Python       kEmhGakjy2c  UgyzPI6Wn7itxeNOTJB4AaABAg
# ..                         ...               ...                         ...
# 225           All About Python       lfUGJuTpj8A  UgwyZx9OGrlx4vE4I7Z4AaABAg
# 226           All About Python       lfUGJuTpj8A  UgxNfCBKTRSNNUxK1vl4AaABAg
# 227           All About Python       lfUGJuTpj8A  UgxroiRBSU_X_6D-w1t4AaABAg
# 228           All About Python       gj6QDxnheic  UgwP_nT5tUX2v3i9Xfh4AaABAg
# 229           All About Python       gj6QDxnheic  UgxG3dWciHsj1nTRN_x4AaABAg
#
#                                     comments_text_list comments_authors_list  \
# 0     Ultimate speech my friend which country are you?           @emmranm369
# 1    My friend please don&#39;t stop the video if y...           @emmranm369
# 2     I&#39;m big fan of you and especially your voice           @emmranm369
# 3    That&#39;s it my friend just you&#39;ve been k...           @emmranm369
# 4    Ji do videos continuously we really miss all y...           @emmranm369
# ..                                                 ...                   ...
# 225                                   Very useful bro😍        @seriously5871
# 226  Part 2 of the series:<br><a href="https://www....       @AllAboutPython
# 227                                Yeah! Amazing video     @astitvavarma1079
# 228                                         Ohooo 👌🏻👌🏻      @amanbashera5454
# 229  If you want content in English, check out my b...       @AllAboutPython
#
#       commented_date_list
# 0    2024-01-03T12:15:02Z
# 1    2024-01-01T06:47:39Z
# 2    2024-01-01T06:45:12Z
# 3    2024-01-01T06:43:36Z
# 4    2023-12-30T15:57:58Z
# ..                    ...
# 225  2021-09-03T13:42:20Z
# 226  2021-05-15T16:48:08Z
# 227  2021-05-14T12:01:03Z
# 228  2021-05-02T17:31:58Z
# 229  2021-05-02T14:25:07Z
#
# [230 rows x 6 columns]
